# %%
import pandas as pd

# %%
df_drama = pd.read_csv("./data/df_drama_kor_all_tot.csv")

# %%
df_drama.head()
# Out:
#        방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0  20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1  20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2  20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3  20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4  20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
#
#          출연진내용      총시청률
# 0  조여정,김강우,정웅인  4.117441
# 1  조여정,김강우,정웅인  5.312815
# 2  오연서,안재현,김슬기  1.505145
# 3  윤시윤,정인선,박성훈  1.390483
# 4  조여정,김강우,정웅인  3.286444

# %%
aa = df_drama.groupby(['프로그램명'])
aa.head()
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간         프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624        99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803        99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027       하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540     싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920        99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...           ...   ...        ...
# 2079  20211226  JTBC        22       430  설강화:SNOWDROP    5회      미니시리즈
# 2080  20211226   tvN        21    223659           불가살    4회      미니시리즈
# 2081  20211227  KBS2        21    224537      꽃피면달생각하고    3회      미니시리즈
# 2084  20211228  KBS2        21    224806      꽃피면달생각하고    4회      미니시리즈
# 2094  20211231   tvN        22       108       배드앤크레이지    5회      미니시리즈
#
#             출연진내용      총시청률
# 0     조여정,김강우,정웅인  4.117441
# 1     조여정,김강우,정웅인  5.312815
# ...

# %%
df_group_channel = df_drama.groupby(['채널명']).count()
dfdf = df_group_channel[['프로그램명']]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
plt.rc("font", family = "malgun gothic")

# %%
dfdf.plot(kind="bar", figsize=[15,15])
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'JTBC'),
#   Text(1, 0, 'KBS2'),
#   Text(2, 0, 'MBC'),
#   Text(3, 0, 'OCN'),
#   Text(4, 0, 'SBS'),
#   Text(5, 0, 'tvN')])
