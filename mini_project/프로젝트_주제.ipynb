# %%
import pandas as pd

# %% [markdown]
# # 채널별 드라마 개수 & 시청률 분석

# %%
drama_132_gr = drama_132.groupby('채널명').count()
drama_132_gr = drama_132_gr.reset_index()

# %%
# 채널 - 프로그램 개수
sns.barplot(data=drama_132_gr, x='채널명', y='프로그램명')
# Out:
# <AxesSubplot:xlabel='채널명', ylabel='프로그램명'>

# %%
drama_132_rate = drama_132.groupby('채널명').mean()
drama_132_rate = drama_132_rate.reset_index()

# %%
sns.barplot(data=drama_132_rate, x='채널명', y='가구평균시청률(%)')
# Out:
# <AxesSubplot:xlabel='채널명', ylabel='가구평균시청률(%)'>

# %% [markdown]
# - 2020년~2021년 동안 Tvn의 드라마 개수가 가장 많지만
# - 시청률 top5 중 4개의 드라마는 sbs드라마임

# %% [markdown]
# # 1. 채널별 온라인이용자반응(동영상 조회수, 게시글 수 , 댓글 수)는 어떠한 차이가 보이는가?

# %%
drama_react
# Out:
#          방송일자   채널명  프로그램시작시간  프로그램종료시간        프로그램명 방송회차명 프로그램장르소분류명  \
# 0    20210402   SBS        22    223547       펜트하우스2   13회      미니시리즈
# 1    20200106   SBS        21    221518     낭만닥터김사부2    1회      미니시리즈
# 2    20210702   SBS        22    232719       펜트하우스3    5회      미니시리즈
# 3    20201026   SBS        22    225024        펜트하우스    1회      미니시리즈
# 4    20200111   tvN        21    223618       사랑의불시착    7회      미니시리즈
# ..        ...   ...       ...       ...          ...   ...        ...
# 127  20200831   SBS        22    223519    브람스를좋아하세요    1회      미니시리즈
# 128  20200902  KBS2        21    220407       동백꽃필무렵    1회      미니시리즈
# 129  20210401   MBC        21    214953         오주인님    4회      미니시리즈
# 130  20210703   tvN        22       655       보이스시즌4    6회      미니시리즈
# 131  20210805   tvN        21    223210  슬기로운의사생활시즌2    7회      미니시리즈
#
#            출연진내용   장르1  장르2  가구평균시청률(%)          게시글수            댓글수  \
# ...

# %%
drama_react_ch = drama_react.groupby('채널명')
drama_react_ch.head()
# Out:
#         방송일자   채널명  프로그램시작시간  프로그램종료시간         프로그램명 방송회차명 프로그램장르소분류명  \
# 0   20210402   SBS        22    223547        펜트하우스2   13회      미니시리즈
# 1   20200106   SBS        21    221518      낭만닥터김사부2    1회      미니시리즈
# 2   20210702   SBS        22    232719        펜트하우스3    5회      미니시리즈
# 3   20201026   SBS        22    225024         펜트하우스    1회      미니시리즈
# 4   20200111   tvN        21    223618        사랑의불시착    7회      미니시리즈
# 5   20200103   SBS        22    223426         스토브리그    6회      미니시리즈
# 6   20200402  JTBC        22    241856         부부의세계    1회      미니시리즈
# 9   20201212   tvN        21    223004          철인왕후    1회      미니시리즈
# 10  20200319   tvN        21    223557      슬기로운의사생활    2회      미니시리즈
# 11  20210403   tvN        21    223016           빈센조   13회      미니시리즈
# 12  20200101  KBS2        22    222624        99억의여자   17회      미니시리즈
# 13  20200203  JTBC        22    240505        이태원클라쓰    1회      미니시리즈
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
drama_react[['동영상조회(K)']]
# Out:
#          동영상조회(K)
# 0    35095.500000
# 1    11238.000000
# 2    22316.600000
# 3    29736.250000
# 4    44437.500000
# ..            ...
# 127   6559.666667
# 128           NaN
# 129    331.000000
# 130           NaN
# 131  11166.400000
#
# [132 rows x 1 columns]

# %%
# 채널 - 동영상조회
plt.rc("font", family = "malgun gothic")

sns.barplot(data=drama_react,x='채널명',y='동영상조회(K)')
plt.show()

# %%
# 채널 - 댓글수
plt.rc("font", family = "malgun gothic")

sns.barplot(data=drama_react,x='채널명',y='댓글수')
plt.show()

# %%
# 채널 - 게시글수
plt.rc("font", family = "malgun gothic")

sns.barplot(data=drama_react,x='채널명',y='게시글수')
plt.show()

# %% [markdown]
# - 채널별로 온라인이용자반응은 SBS 채널이 다른 채널에 비해 압도적으로 많았으며, KBS2 채널이 가장 적은 것으로 나타남
# - KSB1과 SBS 채널의 차이는 동영상 조회수에 있어서 약 5배, 댓글 수에 있어서 ~배, 게시글 수에 있어서 ~배 차이남
# - 하지만 SBS를 제외한 지상파 채널군보다는 TvN이나 Jtbc와 같은 비지상파 채널군이 온라인 이용자 반응이 훨씬 활발하게 나타남
# - SBS가 압도적으로 높인 이유 ?? 펜트하우스1,2,3의 흥행?
# - /
# - +) 통계적으로 유의미한지 알아보기 위해서 => 분산분석 사용해야 함

# %% [markdown]
# # 2. 채널별로 방송프로그램 시청자수(TV시청률, TV-vod/pc, 스마트폰 시청자수)는 어떠한 차이를 보이는가?

# %% [markdown]
# # 3. 온라인이용자반응(동영상조회수, 게시글수, 댓글수)에 영향을 미치는 요인은 무엇인가?

# %% [markdown]
# # 4. 장르와 시청률 & 온라인이용자반응의 관계

# %%
drama_132_1 = drama_132[['채널명','프로그램명','장르1','가구평균시청률(%)']]
drama_132_2 = drama_132[['채널명','프로그램명','장르2','가구평균시청률(%)']]

# %%
drama_132_2 = drama_132_2.rename(columns={'장르2':'장르1'})
drama_132_2
# Out:
#       채널명        프로그램명  장르1  가구평균시청률(%)
# 0     SBS       펜트하우스2  스릴러   20.633333
# 1     SBS     낭만닥터김사부2  NaN   17.350000
# 2     SBS       펜트하우스3  스릴러   15.725000
# 3     SBS        펜트하우스  스릴러   14.200000
# 4     tvN       사랑의불시착  NaN   14.050000
# ..    ...          ...  ...         ...
# 127   SBS    브람스를좋아하세요  NaN    5.600000
# 128  KBS2       동백꽃필무렵  로맨스   13.900000
# 129   MBC         오주인님  코미디    1.600000
# 130   tvN       보이스시즌4   수사    3.800000
# 131   tvN  슬기로운의사생활시즌2  로맨스   14.100000
#
# [132 rows x 4 columns]

# %%
drama_132_3 = pd.concat([drama_132_1,drama_132_2],ignore_index=True, axis=0)

# %%
drama_132_4 = drama_132_3.groupby(['장르1'])
drama_132_4.head()
# Out:
#       채널명     프로그램명  장르1  가구평균시청률(%)
# 0     SBS    펜트하우스2   범죄   20.633333
# 1     SBS  낭만닥터김사부2   의학   17.350000
# 2     SBS    펜트하우스3   범죄   15.725000
# 3     SBS     펜트하우스   범죄   14.200000
# 4     tvN    사랑의불시착  로맨스   14.050000
# ..    ...       ...  ...         ...
# 206   MBC  미쓰리는알고있다   수사    2.900000
# 208  KBS2   바람피면죽는다  코미디    2.900000
# 214  KBS2       출사표  오피스    2.700000
# 221   tvN      나빌레라  스포츠    2.650000
# 230  KBS2      계약우정  코미디    2.200000
#
# [82 rows x 4 columns]

# %%
plt.bar(drama_132_4['장르1'],drama_132_4['가구평균시청률(%)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 plt.bar(drama_132_4['장르1'],drama_132_4['가구평균시청률(%)'])
#
# File ~\anaconda3\envs\django\lib\site-packages\matplotlib\pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
#    2383 @_copy_docstring_and_deprecators(Axes.bar)
#    2384 def bar(
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\envs\django\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
# ...

# %% [markdown]
# - 장르 : 스릴러 시청률이 가장 많음
# - 로맨스는 의외로 낮음 -> 스릴러에 비해 드라마 수가 많음

# %%
drama_132_3[drama_132_3['장르1']=='스릴러']
# Out:
#      채널명   프로그램명  장르1  가구평균시청률(%)
# 132  SBS  펜트하우스2  스릴러   20.633333
# 134  SBS  펜트하우스3  스릴러   15.725000
# 135  SBS   펜트하우스  스릴러   14.200000

# %%
plt.rc("font", family = "malgun gothic")
plt.figure(figsize=((30,10)))
sns.relplot(x=drama_react_1['동영상조회(K)'],
            y=drama_react_1['게시글수'],
            s=drama_react_1['댓글수']/100,
            hue = drama_react_1['채널명'],
           palette="Blues")
plt.xlabel('평균 동영상 조회수(K)', fontsize=12)
plt.ylabel('평균 게시글 수', fontsize=12)
plt.show()

# %% [markdown]
# # 5. 요일과 드라마 시청률의 관계

# %%
drama_data_1
# Out:
#      채널명        프로그램명  가구평균시청률(%)
# 14  KBS2       99억의여자    8.700000
# 13   tvN          빈센조    9.975000
# 12   tvN     슬기로운의사생활   10.100000
# 11   tvN         철인왕후   10.500000
# 10   SBS         모범택시   11.800000
# 9    SBS         원더우먼   11.833333
# 8   JTBC        부부의세계   12.833333
# 7    SBS        스토브리그   13.250000
# 6   KBS2       동백꽃필무렵   13.900000
# 5    tvN       사랑의불시착   14.050000
# 4    tvN  슬기로운의사생활시즌2   14.100000
# 3    SBS        펜트하우스   14.200000
# 2    SBS       펜트하우스3   15.725000
# 1    SBS     낭만닥터김사부2   17.350000
# 0    SBS       펜트하우스2   20.633333

# %%
day = pd.read_csv("./data/total_db/종합반응DB_시청자수_total.csv",encoding='cp949')[['프로그램명','요일']]
day
# Out:
#          프로그램명  요일
# 0        스토브리그   금
# 1       사랑의불시착  토일
# 2     낭만닥터김사부2  월화
# 3          블랙독  월화
# 4    간택-여인들의전쟁  토일
# ..         ...  ..
# 609       트레이서   금
# 610  악의마음을읽는자들   금
# 611      크라임퍼즐  월화
# 612   하트가빛나는순간  월화
# 613  마녀식당으로오세요  수목
#
# [614 rows x 2 columns]

# %%
drama_day = pd.merge(drama_react, day, how ='left', on = '프로그램명')
drama_day = drama_day[['프로그램명','요일','가구평균시청률(%)']]
drama_day
# Out:
#            프로그램명   요일  가구평균시청률(%)
# 0         펜트하우스2    금   20.633333
# 1         펜트하우스2    금   20.633333
# 2         펜트하우스2    금   20.633333
# 3         펜트하우스2    금   20.633333
# 4       낭만닥터김사부2   월화   17.350000
# ..           ...  ...         ...
# 414         오주인님   수목    1.600000
# 415         오주인님   수목    1.600000
# 416         오주인님   수목    1.600000
# 417       보이스시즌4  NaN    3.800000
# 418  슬기로운의사생활시즌2  NaN   14.100000
#
# [419 rows x 3 columns]

# %%
sns.barplot(x='요일',y='가구평균시청률(%)',data=drama_day)
# Out:
# <AxesSubplot:xlabel='요일', ylabel='가구평균시청률(%)'>

# %% [markdown]
# - 금요일 드라마 시청률이 가장 높음

# %% [markdown]
# # 6. 드라마 언제, 얼마나 방송?
# - 첫 회 기준 월별 방`송 드라마 개수
# - 1년 중 어느 달에 가장 많이 새로운 드라마를 선보였는지?

# %% [markdown]
# # 7. 요일별 방송 콘텐츠 비중
# - 월화, 수목, 금, 토일

# %%
drama_day_1 = drama_day.groupby(['요일']).count()
drama_day_1=drama_day_1.reset_index()

# %%
sns.barplot(x='요일',y='프로그램명',data=drama_day_1)
# Out:
# <AxesSubplot:xlabel='요일', ylabel='프로그램명'>

# %% [markdown]
# - 월화, 수목 드라마의 콘텐츠 비중이 가장 큼

# %% [markdown]
# # 8. 성공의 기준이 되는 시청률은 몇 % ?
# - 히스토그램 그리기

# %%
import pandas as pd

# %%
drama_1 = pd.read_csv("./data/data2/드라마_장르_가구평균시청률_중복제거_132개.csv", encoding='cp949')
drama_data = drama_1[['프로그램명','가구평균시청률(%)']]

# %%
# 드라마 시청률 기술통계
drama_data.describe()
# Out:
#        가구평균시청률(%)
# count  132.000000
# mean     4.710922
# std      3.690154
# min      0.233333
# 25%      2.500000
# 50%      3.500000
# 75%      5.608333
# max     20.633333

# %%
plt.rc("font", family = "malgun gothic")
plt.figure(figsize=(10,5))
sns.histplot(drama_data, palette="Reds")

plt.title("2020-2021년 미니시리즈 드라마 시청률 구간별 분포")
plt.xlabel("시청률(%)")
plt.ylabel("드라마개수")
plt.show()

# %% [markdown]
# - 대부분의 드라마가 평균보다 낮은 시청률을 기록했고, 소수의 드라마만 높은 시청률을 기록했다
# - 평균 시청률 : 4.7 %
# - 시청률 중앙값 : 3.5 %
#
# => 시청률이 약 5% 이상 넘었을 때 성공했다고 이야기할 수 있음

# %% [markdown]
# # 9. 시청률이 높은 방송콘텐츠는 인터넷 반응도 높은지?
# - 상위 시청률 15개 드라마 분석
# - 인터넷 반응 - 산점도 그리기
# => 시청률과 시청자 반응을 둘 다 잡은 드라마는 ?

# %%
import matplotlib.pyplot as plt

# %%
# 시청률 상위 15개 드라마
drama_data_1=drama_1[['채널명','프로그램명','가구평균시청률(%)']].sort_values(by='가구평균시청률(%)', ascending=False)
drama_data_1=drama_data_1.reset_index(drop=True)[0:15]
drama_data_1=drama_data_1.sort_values(by='가구평균시청률(%)', ascending=True)

plt.figure(figsize=(10,10))
plt.title("2020-2021 가구평균시청률(%) 상위 15위 드라마")
plt.barh(drama_data_1['프로그램명']+'  '+drama_data_1['채널명'],drama_data_1['가구평균시청률(%)'])
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# - 위그래프를 통해 대부분의 상위 시청률에 해당하는 드라마는 tvn이나 sbs드라마 임을 알 수 있다.
# - JTBC 드라마 중 유일하게 '부부의세계'가 상위 15위건 안에 들었음
# - SBS : 7개
# - Tvn : 5개
# - KBS : 2개

# %%
import pandas as pd
drama_react = pd.read_csv("./data/data2/드라마_인터넷반응.csv")
drama_react
# Out:
#      Unnamed: 0.1  Unnamed: 0      방송일자  채널명  프로그램시작시간  프로그램종료시간        프로그램명  \
# 0               0           0  20210402  SBS        22    223547       펜트하우스2
# 1               1           1  20200106  SBS        21    221518     낭만닥터김사부2
# 2               2           2  20210702  SBS        22    232719       펜트하우스3
# 3               3           3  20201026  SBS        22    225024        펜트하우스
# 4               4           4  20200111  tvN        21    223618       사랑의불시착
# ..            ...         ...       ...  ...       ...       ...          ...
# 126           126         126  20200116  OCN        22    240218           트랩
# 127           127         127  20200831  SBS        22    223519    브람스를좋아하세요
# 128           128         128  20210401  MBC        21    214953         오주인님
# 129           129         129  20210703  tvN        22       655       보이스시즌4
# 130           130         130  20210805  tvN        21    223210  슬기로운의사생활시즌2
#
# ...

# %%
drama_react_1 = drama_react[['프로그램명','게시글수','댓글수','동영상조회(K)','가구평균시청률(%)','채널명']]
drama_react_1=drama_react_1.sort_values(by='가구평균시청률(%)', ascending=False).reset_index(drop=True)[0:15]
drama_react_1.index = drama_react_1.index+1
drama_react_1
# Out:
#           프로그램명          게시글수            댓글수      동영상조회(K)  가구평균시청률(%)   채널명
# 1        펜트하우스2  18210.000000  167850.750000  35095.500000   20.633333   SBS
# 2      낭만닥터김사부2  12662.000000   68780.666667  11238.000000   17.350000   SBS
# 3        펜트하우스3   9340.800000   84294.800000  22316.600000   15.725000   SBS
# 4         펜트하우스  35886.000000  166134.000000  29736.250000   14.200000   SBS
# 5   슬기로운의사생활시즌2   8414.800000   57241.200000  11166.400000   14.100000   tvN
# 6        사랑의불시착  41127.500000  257462.000000  44437.500000   14.050000   tvN
# 7         스토브리그  33935.500000  125258.000000  11750.000000   13.250000   SBS
# 8         부부의세계  37923.666667  262790.000000  36026.333333   12.833333  JTBC
# 9          원더우먼   2822.500000   14261.000000  10107.000000   11.833333   SBS
# 10         모범택시   3486.000000   25273.333333   7556.333333   11.800000   SBS
# 11         철인왕후  11274.250000   67223.000000  23922.000000   10.500000   tvN
# ...

# %%
# 게시글수, 동영상조회수, 댓글 수를 기준으로 드라마의 분포를 시각화
# x축은 평균 동영상 조회수,
# y축은 평균 게시글 수
# 개별 드라마를 의미하는 원의 크기 : 평균 댓글 수

#plt.figure(figsize=((15,10)))
#plt.scatter(drama_react_1['동영상조회(K)'],drama_react_1['게시글수'],
#           s=drama_react_1['댓글수']/50,
#           alpha=0.2)
#plt.xlabel('평균 동영상 조회수(K)', fontsize=12)
#plt.ylabel('평균 게시글 수', fontsize=12)

#plt.colorbar()

#plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.rc("font", family = "malgun gothic")

sns.relplot(x=drama_react_1['동영상조회(K)'],
            y=drama_react_1['게시글수'],
            s=drama_react_1['댓글수']/100,
            hue = drama_react_1['채널명'],
           palette="Reds")
plt.title("게시글수, 동영상조회수, 댓글 수를 기준으로 드라마의 분포를 시각화")

plt.xlabel('평균 동영상 조회수(K)', fontsize=12)
plt.ylabel('평균 게시글 수', fontsize=12)
plt.xlim(0,50000)
plt.ylim(0,50000)

plt.savefig('게시글수, 동영상조회수, 댓글 수를 기준으로 드라마의 분포를 시각화.jpg')

# %% [markdown]
# - 개별 드라마를 의미하는 원은 주로 왼쪽 아래에서 오른쪽 위로 이르는 대각선의 형태로 위치
# => 시청자가 동영상을 많이볼수록 댓글도 크다
# - 원의 크기 : 동영상조회수와 게시글 수가 많은 드라마일수록 원의 크기가 커 댓글 수도 많다는 것을 알 수 있음
# -/
# - 시청률이 높은 드라마가 인터넷에서도 높은 반응을 얻었다면 오른쪽 상단에 위치해야하지만 평균 시청률 5위 드라마인 '사랑의불시착'이 오른쪽 상단에 위치
# - 평균 시청률 1위 드라마 펜트하우스2는 오른쪽 아래에 위치함
# - 오른쪽 상단 위에 있는 드라마 : 사랑의불시착, 부부의세계, 펜트하우스1

# %%
# 피봇 테이블 만들기
df_pivot=drama_react_1.pivot_table(values = '가구평균시청률(%)',
                            index='프로그램명',
                            columns='채널명',
                            aggfunc='mean')
df_pivot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 2>()
#       1 # 피봇 테이블 만들기
# ----> 2 df_pivot=drama_react_1.pivot_table(values = '가구평균시청률(%)',
#       3                             index='프로그램명',
#       4                             columns='채널명',
#       5                             aggfunc='mean')
#       6 df_pivot
#
# File ~\anaconda3\envs\django\lib\site-packages\pandas\core\frame.py:8032, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8015 @Substitution("")
#    8016 @Appender(_shared_docs["pivot_table"])
#    8017 def pivot_table(
#    (...)
#    8028     sort=True,
#    8029 ) -> DataFrame:
#    8030     from pandas.core.reshape.pivot import pivot_table
# -> 8032     return pivot_table(
#    8033         self,
#    8034         values=values,
# ...

# %%
drama_react_1 = drama_react[['프로그램명','채널명','게시글수','댓글수','동영상조회(K)','가구평균시청률(%)','채널명']]
drama_react_1
# Out:
#            프로그램명  채널명          게시글수            댓글수      동영상조회(K)  가구평균시청률(%)  \
# 0         펜트하우스2  SBS  18210.000000  167850.750000  35095.500000   20.633333
# 1       낭만닥터김사부2  SBS  12662.000000   68780.666667  11238.000000   17.350000
# 2         펜트하우스3  SBS   9340.800000   84294.800000  22316.600000   15.725000
# 3          펜트하우스  SBS  35886.000000  166134.000000  29736.250000   14.200000
# 4         사랑의불시착  tvN  41127.500000  257462.000000  44437.500000   14.050000
# ..           ...  ...           ...            ...           ...         ...
# 126           트랩  OCN           NaN            NaN           NaN    4.000000
# 127    브람스를좋아하세요  SBS  17372.333333  121103.333333   6559.666667    5.600000
# 128         오주인님  MBC    687.333333    2575.666667    331.000000    1.600000
# 129       보이스시즌4  tvN           NaN            NaN           NaN    3.800000
# 130  슬기로운의사생활시즌2  tvN   8414.800000   57241.200000  11166.400000   14.100000
#
#      채널명
# 0    SBS
# 1    SBS
# 2    SBS
# ...

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(drama_react_1, annot = True, fmt = ".0f", cmap = "rocket_r")
plt.title("시청률과 인터넷 반응")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 2>()
#       1 plt.figure(figsize = (20, 10))
# ----> 2 sns.heatmap(drama_react_1, annot = True, fmt = ".0f", cmap = "rocket_r")
#       3 plt.title("시청률과 인터넷 반응")
#       4 plt.show()
#
# File ~\anaconda3\envs\django\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %% [markdown]
# # 10. 연령대별로 시청률이 높은 드라마
# - 막대그래프

# %%
online_react = pd.read_csv("./종합반응DB_total.csv",encoding='cp949')
online_react
# Out:
#             프로그램명       방송시작일       채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  \
# 0           스토브리그  2019.12.13      SBS   금  42,064  150,748   14,407  5,394
# 1         사랑의 불시착  2019.12.14      tvN  토일  38,239  249,171   41,477  5,955
# 2      낭만닥터 김사부 2  2020.01.06      SBS  월화  14,613   73,565   11,054  7,492
# 3             블랙독  2019.12.16      tvN  월화   5,876   23,347    5,628  2,662
# 4    간택 - 여인들의 전쟁  2019.12.14  TV CHOS  토일   2,957    9,929    2,151  2,009
# ..            ...         ...      ...  ..     ...      ...      ...    ...
# 609          트레이서  2022.01.07      MBC   금     202      558       10    445
# 610  악의 마음을 읽는 자들  2022.01.14      SBS   금     179      705       55    492
# 611        크라임 퍼즐  2021.11.01      SKY  월화      46       78        5     57
# 612    하트가 빛나는 순간  2021.09.28     EBS1  월화      27    3,210      920     32
# 613    마녀식당으로 오세요  2022.01.05      tvN  수목      12       11        0      2
#
# ...

# %%
drama = pd.read_csv("./data/data2/드라마_출연진_종합파일_최종.csv")
drama
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...        ...   ...        ...
# 2090  20211229   tvN        22    234114      멜랑꼴리아   15회      미니시리즈
# 2091  20211230  KBS2        21    223806     학교2021   12회      미니시리즈
# 2092  20211230  JTBC        22    233422       공작도시    8회      미니시리즈
# 2093  20211230   tvN        22    234134      멜랑꼴리아   16회      미니시리즈
# 2094  20211231   tvN        22       108    배드앤크레이지    5회      미니시리즈
#
#             출연진내용      총시청률     평균시청률   장르1  장르2    인터넷반응지수
# 0     조여정,김강우,정웅인  4.117441  3.675295    범죄   액션  15.725000
# ...

# %% [markdown]
# # 시청률은 가구시청률 이용

# %%
rate = pd.read_csv("./data/data2/종합반응DB시청률_total.csv", encoding='cp949')
rate
# Out:
#          프로그램명       방송시작일      채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  동영상수  \
# 0        스토브리그  2019.12.13     SBS   금  42,064  150,748   14,407  5,394   271
# 1       사랑의불시착  2019.12.14     tvN  토일  38,239  249,171   41,477  5,955   379
# 2     낭만닥터김사부2  2020.01.06     SBS  월화  14,613   73,565   11,054  7,492   331
# 3          블랙독  2019.12.16     tvN  월화   5,876   23,347    5,628  2,662   384
# 4    간택-여인들의전쟁  2019.12.14  TVCHOS  토일   2,957    9,929    2,151  2,009   161
# ..         ...         ...     ...  ..     ...      ...      ...    ...   ...
# 609       트레이서  2022.01.07     MBC   금     202      558       10    445     7
# 610  악의마음을읽는자들  2022.01.14     SBS   금     179      705       55    492    10
# 611      크라임퍼즐  2021.11.01     SKY  월화      46       78        5     57     0
# 612   하트가빛나는순간  2021.09.28    EBS1  월화      27    3,210      920     32     0
# 613  마녀식당으로오세요  2022.01.05     tvN  수목      12       11        0      2     0
#
# ...

# %%
rate[['TVVOD시청자수(K)', 'PC실시간(K)', 'PCVOD(K)', 'Mobile실시간(K)', 'MobileVOD(K)' ]]
# Out:
#     TVVOD시청자수(K) PC실시간(K) PCVOD(K) Mobile실시간(K) MobileVOD(K)
# 0            434      291      386        1,033        1,319
# 1            575      676      602        3,208        2,647
# 2            791      301      497          920        1,391
# 3            243      374      289          967        1,001
# 4             79       86      100          290          354
# ..           ...      ...      ...          ...          ...
# 609            -        -        -            -            -
# 610            -        -        -            -            -
# 611            -        -        -            -            -
# 612            -        -        -           38          175
# 613            -        -        -            -            -
#
# [614 rows x 5 columns]

# %%
drama_rate = rate[['프로그램명','채널','요일','게시글수','댓글수','동영상조회(K)','뉴스','동영상수','가구시청률(%)']]

# %%
# 가구시청률이 0인 row 제거
drama_rate = drama_rate[drama_rate['가구시청률(%)'] != 0]
drama_rate
# Out:
#              프로그램명      채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  동영상수  \
# 0            스토브리그     SBS   금  42,064  150,748   14,407  5,394   271
# 1           사랑의불시착     tvN  토일  38,239  249,171   41,477  5,955   379
# 2         낭만닥터김사부2     SBS  월화  14,613   73,565   11,054  7,492   331
# 3              블랙독     tvN  월화   5,876   23,347    5,628  2,662   384
# 4        간택-여인들의전쟁  TVCHOS  토일   2,957    9,929    2,151  2,009   161
# ..             ...     ...  ..     ...      ...      ...    ...   ...
# 604            구경이    JTBC  토일     561    2,610      143    783   103
# 605           키마이라     OCN  토일     413      689       71    354   186
# 606  KBS드라마스페셜2021    KBS2   금     368    1,763      137  1,055   120
# 607           IDOL    JTBC  월화     303    2,141      329    751   171
# 612       하트가빛나는순간    EBS1  월화      27    3,210      920     32     0
#
#      가구시청률(%)
# 0        12.7
# 1        11.5
# 2        15.1
# 3         4.5
# 4         3.7
# ..        ...
# 604       1.3
# ...

# %%
df_group= drama_rate.groupby(['프로그램명'])
df_group.head()
# Out:
#              프로그램명      채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  동영상수  \
# 0            스토브리그     SBS   금  42,064  150,748   14,407  5,394   271
# 1           사랑의불시착     tvN  토일  38,239  249,171   41,477  5,955   379
# 2         낭만닥터김사부2     SBS  월화  14,613   73,565   11,054  7,492   331
# 3              블랙독     tvN  월화   5,876   23,347    5,628  2,662   384
# 4        간택-여인들의전쟁  TVCHOS  토일   2,957    9,929    2,151  2,009   161
# ..             ...     ...  ..     ...      ...      ...    ...   ...
# 604            구경이    JTBC  토일     561    2,610      143    783   103
# 605           키마이라     OCN  토일     413      689       71    354   186
# 606  KBS드라마스페셜2021    KBS2   금     368    1,763      137  1,055   120
# 607           IDOL    JTBC  월화     303    2,141      329    751   171
# 612       하트가빛나는순간    EBS1  월화      27    3,210      920     32     0
#
#      가구시청률(%)
# 0        12.7
# 1        11.5
# 2        15.1
# 3         4.5
# 4         3.7
# ..        ...
# 604       1.3
# ...

# %%
drama_rate['가구평균시청률(%)'] = df_group[['가구시청률(%)']].transform('mean')
drama_rate.sort_values(by='가구평균시청률(%)',ascending=False)
# Out:
#           프로그램명    채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  동영상수  가구시청률(%)  \
# 111    한번다녀왔습니다  KBS2  토일   3,081   32,166   10,209  3,701   414      24.9
# 68     한번다녀왔습니다  KBS2  토일     948   15,193      877  2,739    95      23.1
# 89     한번다녀왔습니다  KBS2  토일   2,217   19,895    2,895  3,623   295      24.5
# 135    한번다녀왔습니다  KBS2  토일   8,382   96,408   16,836  3,690   334      25.8
# 158    한번다녀왔습니다  KBS2  토일  15,317  117,107   17,991  3,386   319      27.1
# ..          ...   ...  ..     ...      ...      ...    ...   ...       ...
# 521    하트가빛나는순간  EBS1  월화      51      483       36    189     1       0.2
# 580    하트가빛나는순간  EBS1  월화      30    6,203    1,760     10     0       0.1
# 612    하트가빛나는순간  EBS1  월화      27    3,210      920     32     0       0.1
# 476  괴기맨숀:디오리지널   SKY   금      90      261        4    589     6       0.1
# 498  괴기맨숀:디오리지널   SKY   금     111      174        7     46     5       0.1
#
#      가구평균시청률(%)
# 111   26.800000
# 68    26.800000
# ...

# %%
drama_rate
# Out:
#              프로그램명      채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  동영상수  \
# 0            스토브리그     SBS   금  42,064  150,748   14,407  5,394   271
# 1           사랑의불시착     tvN  토일  38,239  249,171   41,477  5,955   379
# 2         낭만닥터김사부2     SBS  월화  14,613   73,565   11,054  7,492   331
# 3              블랙독     tvN  월화   5,876   23,347    5,628  2,662   384
# 4        간택-여인들의전쟁  TVCHOS  토일   2,957    9,929    2,151  2,009   161
# ..             ...     ...  ..     ...      ...      ...    ...   ...
# 604            구경이    JTBC  토일     561    2,610      143    783   103
# 605           키마이라     OCN  토일     413      689       71    354   186
# 606  KBS드라마스페셜2021    KBS2   금     368    1,763      137  1,055   120
# 607           IDOL    JTBC  월화     303    2,141      329    751   171
# 612       하트가빛나는순간    EBS1  월화      27    3,210      920     32     0
#
#      가구시청률(%)  가구평균시청률(%)
# 0        12.7   13.250000
# 1        11.5   14.050000
# 2        15.1   17.350000
# ...

# %%
drama=drama.drop(['총시청률','평균시청률','인터넷반응지수'], axis = 1)
drama
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...        ...   ...        ...
# 2090  20211229   tvN        22    234114      멜랑꼴리아   15회      미니시리즈
# 2091  20211230  KBS2        21    223806     학교2021   12회      미니시리즈
# 2092  20211230  JTBC        22    233422       공작도시    8회      미니시리즈
# 2093  20211230   tvN        22    234134      멜랑꼴리아   16회      미니시리즈
# 2094  20211231   tvN        22       108    배드앤크레이지    5회      미니시리즈
#
#             출연진내용   장르1  장르2
# 0     조여정,김강우,정웅인    범죄   액션
# 1     조여정,김강우,정웅인    범죄   액션
# 2     오연서,안재현,김슬기   로맨스  NaN
# ...

# %%
drama
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...        ...   ...        ...
# 2090  20211229   tvN        22    234114      멜랑꼴리아   15회      미니시리즈
# 2091  20211230  KBS2        21    223806     학교2021   12회      미니시리즈
# 2092  20211230  JTBC        22    233422       공작도시    8회      미니시리즈
# 2093  20211230   tvN        22    234134      멜랑꼴리아   16회      미니시리즈
# 2094  20211231   tvN        22       108    배드앤크레이지    5회      미니시리즈
#
#             출연진내용   장르1  장르2
# 0     조여정,김강우,정웅인    범죄   액션
# 1     조여정,김강우,정웅인    범죄   액션
# 2     오연서,안재현,김슬기   로맨스  NaN
# ...

# %%
drama_rate_re = drama_rate[['프로그램명','가구평균시청률(%)']]
drama_rate_re
# Out:
#              프로그램명  가구평균시청률(%)
# 0            스토브리그   13.250000
# 1           사랑의불시착   14.050000
# 2         낭만닥터김사부2   17.350000
# 3              블랙독    4.400000
# 4        간택-여인들의전쟁    4.250000
# ..             ...         ...
# 604            구경이    1.533333
# 605           키마이라    1.266667
# 606  KBS드라마스페셜2021    1.100000
# 607           IDOL    0.600000
# 612       하트가빛나는순간    0.133333
#
# [460 rows x 2 columns]

# %%
drama_rate_re['프로그램명'].unique()
# Out:
# array(['스토브리그', '사랑의불시착', '낭만닥터김사부2', '블랙독', '간택-여인들의전쟁', '검사내전',
#        '사랑은뷰티풀인생은원더풀', '이태원클라쓰', '99억의여자', '머니게임', '싸이코패스다이어리', '초콜릿',
#        '더게임0시를향하여', '터치', '포레스트', '하자있는인간들', '두번은없다', '드라마스테이지2020',
#        '엑스엑스(XX)', '하이에나', '하이바이마마', '방법', '본대로말하라', '날씨가좋으면찾아가겠어요',
#        '안녕드라큘라', '슬기로운의사생활', '부부의세계', '반의반', '그남자의기억법', '메모리스트',
#        '365운명을거스르는1년', '아무도모른다', '어서와', '루갈', '한번다녀왔습니다', '유별나!문셰프',
#        '어쩌다가족', '더킹영원의군주', '본어게인', '굿캐스팅', '계약우정', '화양연화삶이꽃이되는순간', '꼰대인턴',
#        '오마이베이비', '쌍갑포차', '영혼수선공', '저녁같이드실래요', '야식남녀', '번외수사', '바람과구름과비',
#        '외출', '행복의진수', '사이코지만괜찮아', '편의점샛별이', '아는건별로없지만가족입니다', '우아한친구들',
#        '우리사랑했을까', '악의꽃', '모범형사', '그놈이그놈이다', '출사표', '트레인', '십시일반',
#        '미쓰리는알고있다', '비밀의숲2', '앨리스', '미씽그들이있었다', '내가가장예뻤을때',
#        '연애는귀찮지만외로운건싫어', '시네마틱드라마SF8', '청춘기록', '브람스를좋아하세요?', '18어게인',
#        '트웬티트웬티', '오!삼광빌라!', '경우의수', '거짓말의거짓말', '좀비탐정', '학교기담', '스타트업',
#        '구미호뎐', '도도솔솔라라솔', '펜트하우스', '사생활', '써치', '카이로스', '나를사랑한스파이',
# ...

# %%
len(drama['프로그램명'].unique())
# Out:
# 132

# %%
drama = pd.merge(drama, drama_rate_re, on = '프로그램명', how = 'left')
drama
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...        ...   ...        ...
# 5289  20211230  KBS2        21    223806     학교2021   12회      미니시리즈
# 5290  20211230  JTBC        22    233422       공작도시    8회      미니시리즈
# 5291  20211230   tvN        22    234134      멜랑꼴리아   16회      미니시리즈
# 5292  20211230   tvN        22    234134      멜랑꼴리아   16회      미니시리즈
# 5293  20211231   tvN        22       108    배드앤크레이지    5회      미니시리즈
#
#             출연진내용   장르1  장르2  가구평균시청률(%)
# 0     조여정,김강우,정웅인    범죄   액션        8.70
# 1     조여정,김강우,정웅인    범죄   액션        8.70
# ...

# %%
drama.to_csv("./data/data2/드라마_장르_가구평균시청률.csv")

# %%
drama_132 = drama.drop_duplicates(['프로그램명']).reset_index(drop=True)
drama_132
# Out:
#          방송일자   채널명  프로그램시작시간  프로그램종료시간         프로그램명 방송회차명 프로그램장르소분류명  \
# 0    20200101  KBS2        22    222624        99억의여자   17회      미니시리즈
# 1    20200101   MBC        21    220027       하자있는인간들   22회      미니시리즈
# 2    20200101   tvN        21    224540     싸이코패스다이어리   13회      미니시리즈
# 3    20200102   OCN        22    235816     손THEGUEST    1회      미니시리즈
# 4    20200103   SBS        22    223426         스토브리그    6회      미니시리즈
# ..        ...   ...       ...       ...           ...   ...        ...
# 127  20211208  JTBC        22    233512          공작도시    1회      미니시리즈
# 128  20211217   tvN        22       335       배드앤크레이지    1회      미니시리즈
# 129  20211218  JTBC        22       403  설강화:SNOWDROP    1회      미니시리즈
# 130  20211218   tvN        21    223239           불가살    1회      미니시리즈
# 131  20211220  KBS2        21    224640      꽃피면달생각하고    1회      미니시리즈
#
#            출연진내용   장르1   장르2  가구평균시청률(%)
# 0    조여정,김강우,정웅인    범죄    액션        8.70
# ...

# %%
drama_132.to_csv("./data/드라마_장르_가구평균시청률_중복제거_132개.csv")

# %%
drama_132 = pd.read_csv("./data/data2/드라마_장르_가구평균시청률_중복제거_132개.csv", encoding='cp949')
drama_132[['채널명','프로그램명','출연진내용','장르1','장르2','가구평균시청률(%)']]
# Out:
#       채널명        프로그램명        출연진내용   장르1  장르2  가구평균시청률(%)
# 0     SBS       펜트하우스2   유진,김소연,이지아    범죄  스릴러   20.633333
# 1     SBS     낭만닥터김사부2  한석규,안효섭,이성경    의학  NaN   17.350000
# 2     SBS       펜트하우스3   유진,김소연,이지아    범죄  스릴러   15.725000
# 3     SBS        펜트하우스   이지아,김소연,유진    범죄  스릴러   14.200000
# 4     tvN       사랑의불시착   현빈,손예진,서지혜   로맨스  NaN   14.050000
# ..    ...          ...          ...   ...  ...         ...
# 127   SBS    브람스를좋아하세요  박은빈,김민재,김성철   로맨스  NaN    5.600000
# 128  KBS2       동백꽃필무렵  공효진,강하늘,김지석  미스터리  로맨스   13.900000
# 129   MBC         오주인님   이민기,나나,강민혁   로맨스  코미디    1.600000
# 130   tvN       보이스시즌4  송승헌,이하나,이규형    추리   수사    3.800000
# 131   tvN  슬기로운의사생활시즌2  조정석,유연석,정경호    의학  로맨스   14.100000
#
# [132 rows x 6 columns]

# %%
drama_132[['채널명','프로그램명','가구평균시청률(%)']].sort_values(by='가구평균시청률(%)', ascending=False)
# Out:
#       채널명          프로그램명  가구평균시청률(%)
# 0     SBS         펜트하우스2   20.633333
# 1     SBS       낭만닥터김사부2   17.350000
# 2     SBS         펜트하우스3   15.725000
# 3     SBS          펜트하우스   14.200000
# 131   tvN    슬기로운의사생활시즌2   14.100000
# ..    ...            ...         ...
# 121   tvN            다크홀    0.900000
# 119  JTBC           야식남녀    0.900000
# 122  JTBC           IDOL    0.600000
# 123   MBC     제발그남자만나지마요    0.366667
# 124   MBC  연애는귀찮지만외로운건싫어    0.233333
#
# [132 rows x 3 columns]

# %%
drama_rate.groupby(['프로그램명']).head()
# Out:
#              프로그램명      채널  요일    게시글수      댓글수 동영상조회(K)     뉴스  동영상수  \
# 0            스토브리그     SBS   금  42,064  150,748   14,407  5,394   271
# 1           사랑의불시착     tvN  토일  38,239  249,171   41,477  5,955   379
# 2         낭만닥터김사부2     SBS  월화  14,613   73,565   11,054  7,492   331
# 3              블랙독     tvN  월화   5,876   23,347    5,628  2,662   384
# 4        간택-여인들의전쟁  TVCHOS  토일   2,957    9,929    2,151  2,009   161
# ..             ...     ...  ..     ...      ...      ...    ...   ...
# 604            구경이    JTBC  토일     561    2,610      143    783   103
# 605           키마이라     OCN  토일     413      689       71    354   186
# 606  KBS드라마스페셜2021    KBS2   금     368    1,763      137  1,055   120
# 607           IDOL    JTBC  월화     303    2,141      329    751   171
# 612       하트가빛나는순간    EBS1  월화      27    3,210      920     32     0
#
#      가구시청률(%)  가구평균시청률(%)
# 0        12.7   13.250000
# 1        11.5   14.050000
# 2        15.1   17.350000
# ...

# %%
react  = pd.read_excel("./data/data2/react_count.xlsx")
react=react[['프로그램명','게시글수','댓글수','동영상조회(K)']]

# %%
drama_react = pd.merge(drama_132, react, on = '프로그램명', how = 'left')
drama_react
# Out:
#          방송일자   채널명  프로그램시작시간  프로그램종료시간        프로그램명 방송회차명 프로그램장르소분류명  \
# 0    20210402   SBS        22    223547       펜트하우스2   13회      미니시리즈
# 1    20200106   SBS        21    221518     낭만닥터김사부2    1회      미니시리즈
# 2    20210702   SBS        22    232719       펜트하우스3    5회      미니시리즈
# 3    20201026   SBS        22    225024        펜트하우스    1회      미니시리즈
# 4    20200111   tvN        21    223618       사랑의불시착    7회      미니시리즈
# ..        ...   ...       ...       ...          ...   ...        ...
# 127  20200831   SBS        22    223519    브람스를좋아하세요    1회      미니시리즈
# 128  20200902  KBS2        21    220407       동백꽃필무렵    1회      미니시리즈
# 129  20210401   MBC        21    214953         오주인님    4회      미니시리즈
# 130  20210703   tvN        22       655       보이스시즌4    6회      미니시리즈
# 131  20210805   tvN        21    223210  슬기로운의사생활시즌2    7회      미니시리즈
#
#            출연진내용   장르1  장르2  가구평균시청률(%)          게시글수            댓글수  \
# ...

# %%
#####################################################################################################

# %% [markdown]
# # 드라마별 주연 배우 3명의 나이대와 시청률 사이에 어떤 관계가 있을까

# %%
drama_top30=pd.read_csv("./data/total_db/배우_top30작품_작품개수_나이.csv")
drama_top30
# Out:
#     Unnamed: 0      방송일자   채널명  프로그램시작시간  프로그램종료시간        프로그램명 방송회차명  \
# 0            0  20210402   SBS        22    223547       펜트하우스2   13회
# 1            1  20200106   SBS        21    221518     낭만닥터김사부2    1회
# 2            2  20210702   SBS        22    232719       펜트하우스3    5회
# 3            3  20201026   SBS        22    225024        펜트하우스    1회
# 4            4  20210805   tvN        21    223210  슬기로운의사생활시즌2    7회
# 5            5  20200111   tvN        21    223618       사랑의불시착    7회
# 6            6  20200902  KBS2        21    220407       동백꽃필무렵    1회
# 7            7  20200103   SBS        22    223426        스토브리그    6회
# 8            8  20200402  JTBC        22    241856        부부의세계    1회
# 9            9  20210917   SBS        21    230347         원더우먼    1회
# 10          10  20210409   SBS        22    223735         모범택시    1회
# 11          11  20201212   tvN        21    223004         철인왕후    1회
# ...

# %%
drama_top30=drama_top30[['채널명','프로그램명','가구평균시청률(%)','출연진1','출생1','출연진2','출생2','출연진3','출생3']]

# %%
drama_top30['평균나이대']=(drama_top30['출생1']+drama_top30['출생2']+drama_top30['출생3'])/3
#drama_top30['최고나이']=max(drama_top30['출생1']|drama_top30['출생2']|drama_top30['출생2'])
#drama_top30['최저나이']=min(drama_top30['출생1']|drama_top30['출생2']|drama_top30['출생2'])
drama_top30
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_22896\2651594983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drama_top30['평균나이대']=(drama_top30['출생1']+drama_top30['출생2']+drama_top30['출생3'])/3
#      채널명        프로그램명  가구평균시청률(%) 출연진1  출생1 출연진2  출생2 출연진3  출생3      평균나이대
# 0    SBS       펜트하우스2   20.633333   유진   42  김소연   43  이지아   45  43.333333
# 1    SBS     낭만닥터김사부2   17.350000  한석규   59  안효섭   28  이성경   33  40.000000
# 2    SBS       펜트하우스3   15.725000   유진   42  김소연   43  이지아   45  43.333333
# 3    SBS        펜트하우스   14.200000  이지아   45  김소연   43   유진   42  43.333333
# 4    tvN  슬기로운의사생활시즌2   14.100000  조정석   43  유연석   39  정경호   40  40.666667
# 5    tvN       사랑의불시착   14.050000   현빈   41  손예진   41  서지혜   39  40.333333
# ...

# %%
drama_top30['평균나이대'].mean()
# Out:
# 38.6551724137931

# %%
#drama_top30.to_csv("./data/total_db/top30_드라마_배우_평균나이.csv", index_label=None)

# %%
# !pip install plotly

# %%
# 드라마별 배우 나이의 평균과 시청률
import plotly.express as px


fig = px.scatter(drama_top30,x='평균나이대',y='가구평균시청률(%)', color = "프로그램명", size = "가구평균시청률(%)",
                title = "드라마별 배우 나이의 평균과 시청률")

fig.show()
plt.savefig('드라마별 배우 나이의 평균과 시청률')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [330], in <cell line: 2>()
#       1 # 드라마별 배우 나이의 평균과 시청률
# ----> 2 import plotly.express as px
#       5 fig = px.scatter(drama_top30,x='평균나이대',y='가구평균시청률(%)')
#       6 # make shape
#
# ModuleNotFoundError: No module named 'plotly'

# %%
plt.rc("font", family = "malgun gothic")
plt.figure(figsize=((40,10)))
sns.relplot(x=drama_top30['평균나이대'],
            y=drama_top30['가구평균시청률(%)'],
            hue = drama_react_1['채널명'],
           palette="Blues")
plt.xlabel('평균나이대', fontsize=12)
plt.ylabel('가구평균시청률(%)', fontsize=12)
plt.show()

# %%
# 편성채널별 시청률
import plotly.express as px

fig = px.scatter(drama_top30,x='채널명',y='가구평균시청률(%)',color='프로그램명', size='가구평균시청률(%)')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 import plotly.express as px
#       3 fig = px.scatter(total_df,x='채널명',y='가구평균시청률(%)',color='프로그램명', size='가구평균시청률(%)')
#       5 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # 분석결과
# - 분석결과 출연배우의 연령대와 시청률이 아주 상관이 없지는 않은 것 같다
# - 출연 배우들의 연령이 높다고 시청률이 높은 것은 아니나,
# - 출연 배우들의 연령대가 20대가 주라면 보통 시청률이 낮을 수도 있을 것 같다
# - 주로 청춘 로맨스나, 대학생활 이야기 등을 보는 시청자들은 젊은 층이라고 생각하는데 그들은 티비로 본방송을 보기보다는 OTT서비스 이용을 더 선호하거나 유튜브나 다른 SNS매체를 통해서 해당 드라마를 접하기 때문은 아닐까.라고 예상함
# - 또, 평균 나이대가 30대 후반에서 40대 초반에 시청률이 높을 수 있었던 이유는
# - 여러 가족이 나와서 소위 막장이라고 하는 넓은 분포의 시청자의 흥미를 끌 수 있는 드라마이기 때문이 아닐까 예상
#
# - 예전처럼 케이블 드라마라고 시청률이 마냥 낮다고 할 수 없음
# - tvn에서 방영한 드라마의 시청률이나 드라마 수 또한 밀리지 않는다.

# %%
# 중복으로 존재하는 배우들
display(drama_top30[drama_top30.duplicated['출연진1','출연진1나이']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # 중복으로 존재하는 배우들
# ----> 2 display(drama_top30[drama_top30.duplicated['출연진1','출연진1나이']])
#
# TypeError: 'method' object is not subscriptable

# %%
d1=drama_top30[['프로그램명','출연진1','출생1']]

# %%
d2=drama_top30[['프로그램명','출연진2','출생2']]
d2.rename(columns={'출연진2':'출연진1','출생2':'출생1'},inplace=True)
d2
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_22096\2402716375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2.rename(columns={'출연진2':'출연진1','출생2':'출생1'},inplace=True)
#           프로그램명 출연진1  출생1
# 0        펜트하우스2  김소연   43
# 1      낭만닥터김사부2  안효섭   28
# 2        펜트하우스3  김소연   43
# 3         펜트하우스  김소연   43
# 4   슬기로운의사생활시즌2  유연석   39
# 5        사랑의불시착  손예진   41
# 6        동백꽃필무렵  강하늘   33
# 7         스토브리그  박은빈   31
# 8         부부의세계  박해준   47
# 9          원더우먼  진서연   40
# 10         모범택시   이솜   33
# 11         철인왕후  김정현   33
# 12     슬기로운의사생활  유연석   39
# 13          빈센조  전여빈   34
# 14       99억의여자  김강우   45
# 15       이태원클라쓰  김다미   28
# 16         굿캐스팅  이상엽   40
# 17       갯마을차차차  김선호   37
# 18  암행어사조선비밀수사단  권나라   32
# 19      옷소매붉은끝동  이세영   31
# 20          홍천기  김유정   24
# ...

# %%
d3=drama_top30[['프로그램명','출연진3','출생3']]
d3.rename(columns={'출연진3':'출연진1','출생3':'출생1'},inplace=True)
d3
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_22096\2776935070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d3.rename(columns={'출연진3':'출연진1','출생3':'출생1'},inplace=True)
#           프로그램명 출연진1  출생1
# 0        펜트하우스2  이지아   45
# 1      낭만닥터김사부2  이성경   33
# 2        펜트하우스3  이지아   45
# 3         펜트하우스   유진   42
# 4   슬기로운의사생활시즌2  정경호   40
# 5        사랑의불시착  서지혜   39
# 6        동백꽃필무렵  김지석   42
# 7         스토브리그  오정세   46
# 8         부부의세계  한소희   29
# 9          원더우먼  이상윤   42
# 10         모범택시  김의성   58
# 11         철인왕후  배종옥   59
# 12     슬기로운의사생활  정경호   40
# 13          빈센조  옥택연   35
# 14       99억의여자  정웅인   52
# 15       이태원클라쓰  유재명   50
# 16         굿캐스팅  유인영   39
# 17       갯마을차차차  이상이   32
# 18  암행어사조선비밀수사단  이이경   34
# 19      옷소매붉은끝동   강훈   32
# 20          홍천기   공명   29
# ...

# %%
d4=pd.concat([d1,d2,d3],axis=0)
d4=d4.reset_index(drop=True)

# %%
display(d4[d4.duplicated(['출연진1','출생1'])])
# Out:
#        프로그램명 출연진1  출생1
# 2     펜트하우스3   유진   42
# 12  슬기로운의사생활  조정석   43
# 30  낭만닥터김사부2  안효섭   28
# 31    펜트하우스3  김소연   43
# 32     펜트하우스  김소연   43
# 36     스토브리그  박은빈   31
# 41  슬기로운의사생활  유연석   39
# 58    펜트하우스2  이지아   45
# 60    펜트하우스3  이지아   45
# 61     펜트하우스   유진   42
# 70  슬기로운의사생활  정경호   40
# 85      청춘기록  변우석   32

# %%
# 안효섭, 박은빈, 변우석
# 3명의 배우가 top30의 다른 드라마에 동시에 출연하고 있음


# 펜트하우스와 슬기로운의사생활은 시리즈물이여서 제외

# %%
d4.query("(출연진1 == '안효섭') or (출연진1 == '박은빈') or (출연진1 == '변우석')")
# Out:
#        프로그램명 출연진1  출생1
# 20       홍천기  안효섭   28
# 22        연모  박은빈   31
# 30  낭만닥터김사부2  안효섭   28
# 36     스토브리그  박은빈   31
# 83  꽃피면달생각하고  변우석   32
# 85      청춘기록  변우석   32

# %%
drama_react_1['평균 시청자버즈 총합']=drama_react_1['게시글수']+drama_react_1['댓글수']+drama_react_1['동영상조회(K)']
drama_react_2=drama_react_1[['프로그램명','평균 시청자버즈 총합', '채널명','가구평균시청률(%)']]
drama_react_2
# Out:
#           프로그램명    평균 시청자버즈 총합   채널명  가구평균시청률(%)
# 1        펜트하우스2  221156.250000   SBS   20.633333
# 2      낭만닥터김사부2   92680.666667   SBS   17.350000
# 3        펜트하우스3  115952.200000   SBS   15.725000
# 4         펜트하우스  231756.250000   SBS   14.200000
# 5   슬기로운의사생활시즌2   76822.400000   tvN   14.100000
# 6        사랑의불시착  343027.000000   tvN   14.050000
# 7         스토브리그  170943.500000   SBS   13.250000
# 8         부부의세계  336740.000000  JTBC   12.833333
# 9          원더우먼   27190.500000   SBS   11.833333
# 10         모범택시   36315.666667   SBS   11.800000
# 11         철인왕후  102419.250000   tvN   10.500000
# 12     슬기로운의사생활  117746.750000   tvN   10.100000
# 13          빈센조   90232.600000   tvN    9.975000
# 14       99억의여자   10168.000000  KBS2    8.700000
# 15       이태원클라쓰  194066.000000  JTBC    8.366667

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.rc("font", family = "malgun gothic")

sns.relplot(x=drama_react_1['가구평균시청률(%)'],
            y=drama_react_1['평균 시청자버즈 총합'],
            hue = drama_react_1['채널명'],
            s=400,
           palette="Reds")

# seaborn 추세선 어캐함..

plt.title("시청률과 시청자 버즈 기준 2020-2021년 드라마 분포")

plt.xlabel('가구평균시청률(%)', fontsize=12)
plt.ylabel('평균 시청자버즈 총합', fontsize=12)
# Out:
# Text(38.40378750000001, 0.5, '평균 시청자버즈 총합')
