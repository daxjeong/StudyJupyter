# %%
import pandas as pd

# %%
df = pd.read_csv("./data/df_drama_kor_all_tot.csv")
df
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624     99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803     99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027    하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540  싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920     99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...        ...   ...        ...
# 2090  20211229   tvN        22    234114      멜랑꼴리아   15회      미니시리즈
# 2091  20211230  KBS2        21    223806     학교2021   12회      미니시리즈
# 2092  20211230  JTBC        22    233422       공작도시    8회      미니시리즈
# 2093  20211230   tvN        22    234134      멜랑꼴리아   16회      미니시리즈
# 2094  20211231   tvN        22       108    배드앤크레이지    5회      미니시리즈
#
#                       출연진내용      총시청률
# 0     ['조여정', '김강우', '정웅인']  4.117441
# 1     ['조여정', '김강우', '정웅인']  5.312815
# ...

# %%
df_group= df.groupby(['프로그램명'])
df_group.head()
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간         프로그램명 방송회차명 프로그램장르소분류명  \
# 0     20200101  KBS2        22    222624        99억의여자   17회      미니시리즈
# 1     20200101  KBS2        22    230803        99억의여자   18회      미니시리즈
# 2     20200101   MBC        21    220027       하자있는인간들   22회      미니시리즈
# 3     20200101   tvN        21    224540     싸이코패스다이어리   13회      미니시리즈
# 4     20200102  KBS2        22    222920        99억의여자   19회      미니시리즈
# ...        ...   ...       ...       ...           ...   ...        ...
# 2079  20211226  JTBC        22       430  설강화:SNOWDROP    5회      미니시리즈
# 2080  20211226   tvN        21    223659           불가살    4회      미니시리즈
# 2081  20211227  KBS2        21    224537      꽃피면달생각하고    3회      미니시리즈
# 2084  20211228  KBS2        21    224806      꽃피면달생각하고    4회      미니시리즈
# 2094  20211231   tvN        22       108       배드앤크레이지    5회      미니시리즈
#
#                       출연진내용      총시청률
# 0     ['조여정', '김강우', '정웅인']  4.117441
# ...

# %%
df['평균시청률']=df_group[['총시청률']].transform('mean')
df.sort_values(by='평균시청률',ascending=False)
# Out:
#           방송일자   채널명  프로그램시작시간  프로그램종료시간      프로그램명 방송회차명 프로그램장르소분류명  \
# 1494  20210402   SBS        22    232127     펜트하우스2   13회      미니시리즈
# 1492  20210402   SBS        22    223547     펜트하우스2   13회      미니시리즈
# 1493  20210402   SBS        22    225443     펜트하우스2   13회      미니시리즈
# 1735  20210709   SBS        22    232215     펜트하우스3    6회      미니시리즈
# 1829  20210910   SBS        22    232454     펜트하우스3   14회      미니시리즈
# ...        ...   ...       ...       ...        ...   ...        ...
# 1985  20211122  JTBC        22       438       IDOL    5회      미니시리즈
# 1966  20211115  JTBC        22      2004       IDOL    3회      미니시리즈
# 2002  20211129  JTBC        22       323       IDOL    7회      미니시리즈
# 8     20200102   OCN        22    235816  손THEGUEST    1회      미니시리즈
# 49    20200116   OCN        22    240218         트랩    1회      미니시리즈
#
#                       출연진내용       총시청률      평균시청률
# 1494   ['유진', '김소연', '이지아']  15.482879  14.395862
# ...

# %%
fig = plt.figure()

fig.patch.set_facecolor('xkcd:white')
plt.rc('font', family = 'Malgun Gothic')

# %%
# 평균시청률 5이상
df_5 = df[df['평균시청률'] > 5]
df_5
# Out:
#           방송일자  채널명  프로그램시작시간  프로그램종료시간     프로그램명 방송회차명 프로그램장르소분류명  \
# 9     20200103  SBS        22    223426     스토브리그    6회      미니시리즈
# 10    20200103  SBS        22    230852     스토브리그    6회      미니시리즈
# 11    20200104  SBS        22    223923     스토브리그    7회      미니시리즈
# 12    20200104  SBS        22    230603     스토브리그    7회      미니시리즈
# 13    20200106  SBS        21    221518  낭만닥터김사부2    1회      미니시리즈
# ...        ...  ...       ...       ...       ...   ...        ...
# 1928  20211030  SBS        21    230400      원더우먼   14회      미니시리즈
# 1930  20211030  tvN        21    221934       지리산    3회      미니시리즈
# 1932  20211031  tvN        21    221845       지리산    4회      미니시리즈
# 1941  20211105  SBS        22    231027      원더우먼   15회      미니시리즈
# 1943  20211106  SBS        21    230431      원더우먼   16회      미니시리즈
#
#                       출연진내용      총시청률     평균시청률
# 9     ['남궁민', '박은빈', '오정세']  5.189818  7.027899
# 10    ['남궁민', '박은빈', '오정세']  6.896261  7.027899
# ...

# %%
len(df_5['프로그램명'].unique())
# Out:
# 13

# %%
len(df_group['프로그램명'].unique())
# Out:
# 132

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
plt.rc('font', size=20)

sns.set_palette("pastel")
plt.figure(figsize = (20, 10))
sns.barplot(df_5['프로그램명'], df_5['평균시청률'])
plt.xlabel("드라마 이름")
plt.ylabel("평균 시청률")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\admin\anaconda3\envs\django\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.describe()
# Out:
#                방송일자     프로그램시작시간       프로그램종료시간         총시청률        평균시청률
# count  2.095000e+03  2095.000000    2095.000000  2095.000000  2095.000000
# mean   2.020414e+07    21.473508  222303.341766     2.584331     2.584331
# std    4.748779e+03     0.499417   28201.638859     2.268787     2.062048
# min    2.020010e+07    21.000000      24.000000     0.075322     0.186361
# 25%    2.020061e+07    21.000000  221931.500000     1.112084     1.172974
# 50%    2.020102e+07    21.000000  223745.000000     1.847169     1.946270
# 75%    2.021043e+07    22.000000  230507.000000     3.220335     3.312360
# max    2.021123e+07    22.000000  242005.000000    15.482879    14.395862

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
df['프로그램명']

# %%
import openpyxl

# %%
aa = pd.read_excel("./data/종합반응DB_2020년01월_2021년01월.xls")
aa
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [97], in <cell line: 2>()
#       1 import openpyxl
# ----> 2 aa = pd.read_excel("./data/종합반응DB_2020년01월_2021년01월.xls")
#       3 aa
#
# File ~\anaconda3\envs\django\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
